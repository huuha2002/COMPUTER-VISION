# %%
#!pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 932.9 kB/s eta 0:00:42
#     --------------------------------------- 0.8/38.8 MB 860.9 kB/s eta 0:00:45
#     --------------------------------------- 0.8/38.8 MB 860.9 kB/s eta 0:00:45
#    - -------------------------------------- 1.0/38.8 MB 825.2 kB/s eta 0:00:46
#    - -------------------------------------- 1.0/38.8 MB 825.2 kB/s eta 0:00:46
#    - -------------------------------------- 1.3/38.8 MB 762.6 kB/s eta 0:00:50
#    - -------------------------------------- 1.6/38.8 MB 777.0 kB/s eta 0:00:48
#    - -------------------------------------- 1.6/38.8 MB 777.0 kB/s eta 0:00:48
#    - -------------------------------------- 1.8/38.8 MB 812.0 kB/s eta 0:00:46
# ...

# %%
def display(title, img):
    cv2.imshow(title, img)
    # Chờ một khoảng thời gian
    cv2.waitKey(0)
    # Đóng window
    cv2.destroyWindow(title)

# %%
# Import thư viện
import cv2

# %%
path= 'C:/Users/creep/Documents/THIGIACMAYTINH/HOA2.jpg'
img = cv2.imread(path)
# In thông tin của ảnh
print(img)
# Out:
# [[[221 176 133]
#   [222 177 134]
#   [222 177 134]
#   ...
#   [212 162 120]
#   [213 163 121]
#   [214 164 122]]
#
#  [[221 176 133]
#   [222 177 134]
#   [222 177 134]
#   ...
#   [213 164 120]
#   [213 163 121]
#   [213 164 120]]
#
#  [[221 176 133]
#   [222 177 134]
#   [222 177 133]
#   ...
#   [213 164 118]
#   [211 162 118]
#   [209 160 114]]
#
#  ...
#
#  [[224 193 154]
#   [224 193 154]
#   [223 192 153]
#   ...
#   [216 178 136]
#   [217 179 137]
#   [217 179 137]]
#
#  [[224 193 154]
#   [223 192 153]
#   [223 192 153]
#   ...
#   [217 179 137]
#   [217 179 137]
#   [217 179 137]]
#
#  [[223 192 153]
#   [222 191 152]
#   [222 191 152]
#   ...
#   [215 177 135]
#   [215 177 135]
#   [216 178 136]]]

# %%
# Lấy kích thước
print(img.shape)
x, y, z = img.shape
print(x)
print(y)
print(z)
# Out:
# (800, 800, 3)
# 800
# 800
# 3

# %%
# Hiển thị ảnh
cv2.imshow('Window', img)
# Chờ một khoảng thời gian
cv2.waitKey(5000)
# Đóng window
cv2.destroyWindow('Window')

# %%
# Tách màu
b, g, r = cv2.split(img) #cv2 nhận theo thứ tự blue, green, red
cv2.imshow('Window', img)
cv2.imshow('Red', r)
cv2.imshow('Green', g)
cv2.imshow('Blue', b)
# Chờ một khoảng thời gian(Nhấn nút bất kì để đóng ảnh)
cv2.waitKey(0)
# Đóng window
cv2.destroyAllWindows()

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)#chuyển xám
img_2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)#chuyển số của BGR sang RGB
cv2.imshow('Window', img)
cv2.imshow('gray_img', gray_img)
cv2.imshow('img_2', img_2)
# Chờ một khoảng thời gian
cv2.waitKey(0)
# Đóng window
cv2.destroyAllWindows()

# %%
# Thay đổi thông số của điểm ảnh
height, width, z = img.shape
quater_h = height/2
quater_w = width/2

# geen color
green_color = (0,255,0)

# copy ảnh
img2 = img.copy()

# thay đổi màu của góc 1/4 bên trái trên

for y in range(int(quater_h)):
    for x in range(int(quater_w)):
        img2[y, x] = green_color
# Hiển thị
display('Window', img)
display('Window-2', img2)
