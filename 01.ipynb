# %%
# Import lớp Image
from PIL import Image

# %%
# Thư mục chứa hình ảnh
dir = 'C:/Users/creep/Documents/THIGIACMAYTINH'

# %%
# Đường dẫn đến hình ảnh
image_path = dir +'/HOA2.jpg'
print(image_path)
# Out:
# C:/Users/creep/Documents/THIGIACMAYTINH/HOA2.jpg

# %%
# Sử dụng Image.open() đọc ảnh
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800>

# %%
# In một số thông tin
# In định dạng ảnh
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
# In ra size
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (800, 800)

# %%
# Lưu ảnh và chuyển đổi ảnh
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
# Đóng tập tin
img01.close()
